# %% [markdown]
# # Random Forest : Prosper Loan Dataset
#
# A decision tree a learned set of rules that allows us to make decisions on data.
#
# We are going to look at the prosper loan dataset.  This dataset shows a history of loans made by Prosper.

# %%
# initialize Spark Session
import os
import sys
top_dir = os.path.abspath(os.path.join(os.getcwd(), "../"))
if top_dir not in sys.path:
    sys.path.append(top_dir)

from init_spark import init_spark
spark = init_spark()
spark
# Out:
# Initializing Spark...
# Spark found in :  /home/ubuntu/spark
# Spark config:
# 	 spark.app.name=TestApp
# 	spark.master=local[*]
# 	executor.memory=2g
# 	spark.sql.warehouse.dir=/tmp/tmpsdh5f838
# 	some_property=some_value
# Spark UI running on port 4042
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://ip-172-16-0-107.ec2.internal:4042">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>TestApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## Step 1: Load the Data

# %%
## small file, start with this
datafile = "/data/prosper-loan/prosper-loan-data-sample.csv"

## this is a large file
#datafile = "/data/prosper-loan/prosper-loan-data.csv.gz"

# %%
# %%time

data = spark.read. \
          option("header", "true"). \
          option("inferSchema", "true").  \
          csv(datafile)
# Out:
# CPU times: user 4 ms, sys: 0 ns, total: 4 ms
# Wall time: 3.89 s

# %%
print("read {:,} records".format(data.count()))
# schema
data.printSchema()
# Out:
# read 200 records
# root
#  |-- Term: integer (nullable = true)
#  |-- LoanStatus: integer (nullable = true)
#  |-- BorrowerRate: double (nullable = true)
#  |-- ProsperRating (numeric): double (nullable = true)
#  |-- ProsperScore: double (nullable = true)
#  |-- ListingCategory: string (nullable = true)
#  |-- BorrowerState: string (nullable = true)
#  |-- EmploymentStatus: string (nullable = true)
#  |-- EmploymentStatusDuration: double (nullable = true)
#  |-- IsBorrowerHomeowner: boolean (nullable = true)
#  |-- CreditScore: double (nullable = true)
#  |-- CurrentCreditLines: double (nullable = true)
#  |-- OpenCreditLines: double (nullable = true)
#  |-- TotalCreditLinespast7years: double (nullable = true)
#  |-- OpenRevolvingAccounts: integer (nullable = true)
#  |-- OpenRevolvingMonthlyPayment: double (nullable = true)
#  |-- InquiriesLast6Months: double (nullable = true)
#  |-- TotalInquiries: double (nullable = true)
#  |-- CurrentDelinquencies: double (nullable = true)
#  |-- AmountDelinquent: double (nullable = true)
#  |-- DelinquenciesLast7Years: double (nullable = true)
#  |-- PublicRecordsLast10Years: double (nullable = true)
#  |-- PublicRecordsLast12Months: double (nullable = true)
#  |-- RevolvingCreditBalance: double (nullable = true)
#  |-- BankcardUtilization: double (nullable = true)
#  |-- AvailableBankcardCredit: double (nullable = true)
#  |-- TotalTrades: double (nullable = true)
#  |-- TradesNeverDelinquent (percentage): double (nullable = true)
#  |-- TradesOpenedLast6Months: double (nullable = true)
#  |-- DebtToIncomeRatio: double (nullable = true)
#  |-- IncomeVerifiable: boolean (nullable = true)
#  |-- StatedMonthlyIncome: double (nullable = true)
#  |-- TotalProsperLoans: double (nullable = true)
#  |-- TotalProsperPaymentsBilled: double (nullable = true)
#  |-- OnTimeProsperPayments: double (nullable = true)
#  |-- ProsperPaymentsLessThanOneMonthLate: double (nullable = true)
#  |-- ProsperPaymentsOneMonthPlusLate: double (nullable = true)
#  |-- ProsperPrincipalBorrowed: double (nullable = true)
#  |-- ProsperPrincipalOutstanding: double (nullable = true)
#  |-- LoanOriginalAmount: integer (nullable = true)
#  |-- MonthlyLoanPayment: double (nullable = true)
#  |-- Recommendations: integer (nullable = true)
#  |-- InvestmentFromFriendsCount: integer (nullable = true)
#  |-- InvestmentFromFriendsAmount: double (nullable = true)
#  |-- Investors: integer (nullable = true)
#  |-- YearsWithCredit: integer (nullable = true)

# %%
## print with pandas
data.limit(10).toPandas()
# Out:
#    Term  LoanStatus  BorrowerRate  ProsperRating (numeric)  ProsperScore  \
# 0    36           1        0.0789                      7.0           9.0
# 1    36           0        0.1450                      4.0           6.0
# 2    36           1        0.1707                      4.0           6.0
# 3    36           1        0.0830                      7.0           9.0
# 4    36           1        0.1550                      4.0           6.0
# 5    36           1        0.2099                      4.0           6.0
# 6    36           1        0.0950                      7.0           9.0
# 7    36           1        0.0670                      4.0           6.0
# 8    36           1        0.1330                      4.0           6.0
# 9    36           1        0.1000                      4.0           6.0
#
#   ListingCategory BorrowerState EmploymentStatus  EmploymentStatusDuration  \
# 0            Debt            VA         Employed                       9.0
# 1         Unknown            OR        Part-time                      15.0
# 2            Debt            UT        Full-time                      22.0
# 3           Other            VA        Full-time                     175.0
# 4            Debt            IL        Full-time                      18.0
# 5           Other            IN         Employed                      77.0
# 6            Auto            MI        Full-time                      43.0
# 7        Business            PA        Full-time                      40.0
# 8         Unknown            MD    Self-employed                       5.0
# 9        Personal            NY        Full-time                      42.0
#
#    IsBorrowerHomeowner  ...  ProsperPaymentsOneMonthPlusLate  \
# 0                 True  ...                              0.0
# 1                False  ...                              0.0
# 2                 True  ...                              0.0
# 3                 True  ...                              0.0
# 4                False  ...                              0.0
# 5                 True  ...                              0.0
# 6                 True  ...                              0.0
# 7                False  ...                              0.0
# 8                 True  ...                              0.0
# 9                 True  ...                              0.0
#
#    ProsperPrincipalBorrowed  ProsperPrincipalOutstanding  LoanOriginalAmount  \
# 0                       0.0                         0.00               17300
# 1                       0.0                         0.00                9500
# 2                       0.0                         0.00                7200
# 3                       0.0                         0.00                4500
# 4                       0.0                         0.00                8000
# 5                       0.0                         0.00                4000
# 6                   10000.0                      5584.95                6000
# 7                       0.0                         0.00                1250
# 8                       0.0                         0.00                8000
# 9                       0.0                         0.00               25000
#
#    MonthlyLoanPayment  Recommendations  InvestmentFromFriendsCount  \
# 0              541.24                0                           0
# 1              327.00                0                           0
# 2              256.95                0                           0
# 3              141.64                0                           0
# 4              277.14                0                           0
# 5              150.68                0                           0
# 6              192.20                0                           0
# 7               38.43                0                           0
# 8              270.71                0                           0
# 9              797.25                0                           0
#
#    InvestmentFromFriendsAmount  Investors  YearsWithCredit
# 0                          0.0        169               20
# 1                          0.0        171               23
# 2                          0.0        216               16
# 3                          0.0        151               18
# 4                          0.0        140               14
# 5                          0.0         74               22
# 6                          0.0        216               21
# 7                          0.0         70               14
# 8                          0.0        242               24
# 9                          0.0        730               30
#
# [10 rows x 46 columns]

# %%
## select a few columns 
## start with: 'LoanStatus',  'EmploymentStatus', 'CreditScore', 'StatedMonthlyIncome'
## we add more later

select_columns = ['LoanStatus',  'ProsperScore', 'EmploymentStatus', 'CreditScore', 'StatedMonthlyIncome', 'ListingCategory']

## Note : vector columns can only have Numbers, don't include Categorical columns here
## And dfefinitely not 'LoanStatus'  (if you are curiuos include and see what happens!)
vector_columns = [  'ProsperScore', 'EmpIndex', 'CreditScore', 'StatedMonthlyIncome']

# %%
## Display

prosper = data.select(select_columns)  
prosper.printSchema()

prosper.limit(10).toPandas()
# Out:
# root
#  |-- LoanStatus: integer (nullable = true)
#  |-- ProsperScore: double (nullable = true)
#  |-- EmploymentStatus: string (nullable = true)
#  |-- CreditScore: double (nullable = true)
#  |-- StatedMonthlyIncome: double (nullable = true)
#  |-- ListingCategory: string (nullable = true)
#    LoanStatus  ProsperScore EmploymentStatus  CreditScore  \
# 0           1           9.0         Employed        740.0
# 1           0           6.0        Part-time        760.0
# 2           1           6.0        Full-time        680.0
# 3           1           9.0        Full-time        800.0
# 4           1           6.0        Full-time        600.0
# 5           1           6.0         Employed        760.0
# 6           1           9.0        Full-time        820.0
# 7           1           6.0        Full-time        780.0
# 8           1           6.0    Self-employed        680.0
# 9           1           6.0        Full-time        820.0
#
#    StatedMonthlyIncome ListingCategory
# 0         10416.666667            Debt
# 1             0.000000         Unknown
# 2          5000.000000            Debt
# 3          5000.000000           Other
# 4          2625.000000            Debt
# 5          4992.666667           Other
# 6          4583.333333            Auto
# 7          2216.666667        Business
# 8          8433.333333         Unknown
# 9         16666.666667        Personal

# %% [markdown]
# ## Step 2 : Clean Data

# %%
# Drop any NA values.  Using `dataframe.na.drop()`
prosper_clean = prosper.na.drop()
print("Original record count {:,}, cleaned records count {:,},  dropped {:,}"\
      .format(prosper.count(), prosper_clean.count(), (prosper.count() - prosper_clean.count())))
prosper_clean.show()
# Out:
# Original record count 200, cleaned records count 200,  dropped 0
# +----------+------------+----------------+-----------+-------------------+---------------+
# |LoanStatus|ProsperScore|EmploymentStatus|CreditScore|StatedMonthlyIncome|ListingCategory|
# +----------+------------+----------------+-----------+-------------------+---------------+
# |         1|         9.0|        Employed|      740.0|       10416.666667|           Debt|
# |         0|         6.0|       Part-time|      760.0|                0.0|        Unknown|
# |         1|         6.0|       Full-time|      680.0|             5000.0|           Debt|
# |         1|         9.0|       Full-time|      800.0|             5000.0|          Other|
# |         1|         6.0|       Full-time|      600.0|             2625.0|           Debt|
# |         1|         6.0|        Employed|      760.0|        4992.666667|          Other|
# |         1|         9.0|       Full-time|      820.0|        4583.333333|           Auto|
# |         1|         6.0|       Full-time|      780.0|        2216.666667|       Business|
# |         1|         6.0|   Self-employed|      680.0|        8433.333333|        Unknown|
# |         1|         6.0|       Full-time|      820.0| 16666.666666999998|       Personal|
# |         1|         7.0|       Full-time|      700.0|            18750.0|          Other|
# |         1|         6.0|       Full-time|      600.0|             4250.0|           Debt|
# |         1|         4.0|        Employed|      700.0|        2666.666667|           Debt|
# |         1|        10.0|           Other|      800.0|        5916.666667|          Taxes|
# |         0|         6.0|       Full-time|      520.0|        5171.166667|        Unknown|
# |         1|         6.0|       Full-time|      640.0|        2666.666667|        Unknown|
# |         1|         5.0|        Employed|      660.0|        6666.666667|           Debt|
# |         1|         6.0|       Full-time|      740.0|             7500.0|        Unknown|
# |         1|         6.0|       Full-time|      680.0|        2333.333333|       Personal|
# |         1|         6.0|       Full-time|      680.0|             2750.0|           Auto|
# +----------+------------+----------------+-----------+-------------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### Look at some summary data

# %%
prosper_clean.groupBy('LoanStatus').count().show()
prosper_clean.groupBy('EmploymentStatus').count().show()
# Out:
# +----------+-----+
# |LoanStatus|count|
# +----------+-----+
# |         1|  136|
# |         0|   64|
# +----------+-----+
#
# +----------------+-----+
# |EmploymentStatus|count|
# +----------------+-----+
# |        Employed|   73|
# |       Part-time|    6|
# |   Self-employed|   11|
# |    Not employed|    1|
# |           Other|    1|
# |       Full-time|  106|
# |         Retired|    2|
# +----------------+-----+

# %% [markdown]
# **=> What does that say about the cardinality of these categorical columns? ***

# %% [markdown]
# ## Step 3: Converting Categorical columns
#
# Convert categorical columns to numeric.
# Here let's convert **EmploymentStatus** column

# %%
from pyspark.ml.feature import StringIndexer

strIndexer_employment = StringIndexer(inputCol="EmploymentStatus", outputCol="EmpIndex")
prosper_indexed = strIndexer_employment.fit(prosper_clean).transform(prosper_clean)

prosper_indexed.limit(10).toPandas()
# Out:
#    LoanStatus  ProsperScore EmploymentStatus  CreditScore  \
# 0           1           9.0         Employed        740.0
# 1           0           6.0        Part-time        760.0
# 2           1           6.0        Full-time        680.0
# 3           1           9.0        Full-time        800.0
# 4           1           6.0        Full-time        600.0
# 5           1           6.0         Employed        760.0
# 6           1           9.0        Full-time        820.0
# 7           1           6.0        Full-time        780.0
# 8           1           6.0    Self-employed        680.0
# 9           1           6.0        Full-time        820.0
#
#    StatedMonthlyIncome ListingCategory  EmpIndex
# 0         10416.666667            Debt       1.0
# 1             0.000000         Unknown       3.0
# 2          5000.000000            Debt       0.0
# 3          5000.000000           Other       0.0
# 4          2625.000000            Debt       0.0
# 5          4992.666667           Other       1.0
# 6          4583.333333            Auto       0.0
# 7          2216.666667        Business       0.0
# 8          8433.333333         Unknown       2.0
# 9         16666.666667        Personal       0.0

# %% [markdown]
# ## Step 4: Build feature vectors using VectorAssembler.

# %%
from pyspark.ml.feature import VectorAssembler

assembler = VectorAssembler(inputCols=vector_columns, outputCol="features")
feature_vector = assembler.transform(prosper_indexed)
feature_vector = feature_vector.withColumn("label", feature_vector["LoanStatus"])

feature_vector.limit(10).toPandas()
# Out:
#    LoanStatus  ProsperScore EmploymentStatus  CreditScore  \
# 0           1           9.0         Employed        740.0
# 1           0           6.0        Part-time        760.0
# 2           1           6.0        Full-time        680.0
# 3           1           9.0        Full-time        800.0
# 4           1           6.0        Full-time        600.0
# 5           1           6.0         Employed        760.0
# 6           1           9.0        Full-time        820.0
# 7           1           6.0        Full-time        780.0
# 8           1           6.0    Self-employed        680.0
# 9           1           6.0        Full-time        820.0
#
#    StatedMonthlyIncome ListingCategory  EmpIndex  \
# 0         10416.666667            Debt       1.0
# 1             0.000000         Unknown       3.0
# 2          5000.000000            Debt       0.0
# 3          5000.000000           Other       0.0
# 4          2625.000000            Debt       0.0
# 5          4992.666667           Other       1.0
# 6          4583.333333            Auto       0.0
# 7          2216.666667        Business       0.0
# 8          8433.333333         Unknown       2.0
# 9         16666.666667        Personal       0.0
#
#                                 features  label
# 0        [9.0, 1.0, 740.0, 10416.666667]      1
# 1                 [6.0, 3.0, 760.0, 0.0]      0
# 2              [6.0, 0.0, 680.0, 5000.0]      1
# 3              [9.0, 0.0, 800.0, 5000.0]      1
# 4              [6.0, 0.0, 600.0, 2625.0]      1
# 5         [6.0, 1.0, 760.0, 4992.666667]      1
# 6         [9.0, 0.0, 820.0, 4583.333333]      1
# 7         [6.0, 0.0, 780.0, 2216.666667]      1
# 8         [6.0, 2.0, 680.0, 8433.333333]      1
# 9  [6.0, 0.0, 820.0, 16666.666666999998]      1

# %% [markdown]
# ## Step 5: Split Data into training and test.
#
# We will split our the data up into training and test.  (You know the drill by now).
#
# **=> TODO: Split dataset into 70% training, 30% validation**

# %%
# Split the data into training and test sets (30% held out for testing)
(training, test) =  feature_vector.randomSplit([.7,.3])
print("training set = " , training.count())
print("testing set = " , test.count())
# Out:
# training set =  147
# testing set =  53

# %% [markdown]
# ## Step 6: Random Forest

# %% [markdown]
# ### 6.1 Create RF

# %%
from pyspark.ml.classification import RandomForestClassifier

## TODO : Create a RandomForest with numTrees=20  and maxBins=10000

rf = RandomForestClassifier(labelCol="label", featuresCol="features", \
                            numTrees=20, maxBins=10000)

# %% [markdown]
# ### 6.2 Train the RF

# %%
# %%time
print ("training starting...")
## TODO : train in training data
rf_model = rf.fit(training)
print ("training done.")

## TODO : NOtice the time it took for training
## Is it more or less than decision trees?
# Out:
# training starting...
# training done.
# CPU times: user 8 ms, sys: 8 ms, total: 16 ms
# Wall time: 1.69 s

# %% [markdown]
# ### 6.3 Print RF
# **==>Q : How many nodes the tree has?**

# %%
## print the model
print(rf_model)
print()
print(rf_model.toDebugString)
# Out:
# RandomForestClassificationModel (uid=RandomForestClassifier_108c5f683403) with 20 trees
#
# RandomForestClassificationModel (uid=RandomForestClassifier_108c5f683403) with 20 trees
#   Tree 0 (weight 1.0):
#     If (feature 3 <= 7166.666666499999)
#      If (feature 2 <= 550.0)
#       Predict: 0.0
#      Else (feature 2 > 550.0)
#       If (feature 3 <= 7014.791666499999)
#        If (feature 1 in {3.0})
#         Predict: 0.0
#        Else (feature 1 not in {3.0})
#         Predict: 1.0
#       Else (feature 3 > 7014.791666499999)
#        Predict: 0.0
#     Else (feature 3 > 7166.666666499999)
#      If (feature 3 <= 12083.333333)
#       If (feature 2 <= 690.0)
#        If (feature 3 <= 8316.666666500001)
#         Predict: 1.0
#        Else (feature 3 > 8316.666666500001)
#         If (feature 3 <= 8583.333333499999)
#          Predict: 0.0
#         Else (feature 3 > 8583.333333499999)
#          Predict: 1.0
#       Else (feature 2 > 690.0)
#        Predict: 1.0
#      Else (feature 3 > 12083.333333)
#       Predict: 0.0
#   Tree 1 (weight 1.0):
#     If (feature 3 <= 6481.25)
#      If (feature 3 <= 0.0416665)
#       Predict: 0.0
#      Else (feature 3 > 0.0416665)
#       If (feature 2 <= 630.0)
#        If (feature 0 <= 3.5)
#         Predict: 1.0
#        Else (feature 0 > 3.5)
#         Predict: 0.0
#       Else (feature 2 > 630.0)
#        If (feature 3 <= 6166.666666499999)
#         If (feature 1 in {2.0})
#          Predict: 0.0
#         Else (feature 1 not in {2.0})
#          Predict: 1.0
#        Else (feature 3 > 6166.666666499999)
#         Predict: 0.0
#     Else (feature 3 > 6481.25)
#      If (feature 0 <= 3.5)
#       If (feature 2 <= 670.0)
#        Predict: 0.0
#       Else (feature 2 > 670.0)
#        Predict: 1.0
#      Else (feature 0 > 3.5)
#       If (feature 3 <= 7056.458333)
#        If (feature 2 <= 690.0)
#         Predict: 1.0
#        Else (feature 2 > 690.0)
#         If (feature 3 <= 6958.333333500001)
#          Predict: 1.0
#         Else (feature 3 > 6958.333333500001)
#          Predict: 0.0
#       Else (feature 3 > 7056.458333)
#        Predict: 1.0
#   Tree 2 (weight 1.0):
#     If (feature 3 <= 0.0416665)
#      Predict: 0.0
#     Else (feature 3 > 0.0416665)
#      If (feature 2 <= 730.0)
#       If (feature 0 <= 2.5)
#        Predict: 0.0
#       Else (feature 0 > 2.5)
#        Predict: 1.0
#      Else (feature 2 > 730.0)
#       Predict: 1.0
#   Tree 3 (weight 1.0):
#     If (feature 3 <= 3400.0)
#      If (feature 2 <= 730.0)
#       If (feature 1 in {2.0})
#        Predict: 1.0
#       Else (feature 1 not in {2.0})
#        If (feature 3 <= 1773.166667)
#         Predict: 0.0
#        Else (feature 3 > 1773.166667)
#         If (feature 1 in {3.0})
#          Predict: 1.0
#         Else (feature 1 not in {3.0})
#          Predict: 0.0
#      Else (feature 2 > 730.0)
#       If (feature 3 <= 2254.8333334999998)
#        Predict: 1.0
#       Else (feature 3 > 2254.8333334999998)
#        If (feature 3 <= 3250.0)
#         Predict: 0.0
#        Else (feature 3 > 3250.0)
#         Predict: 1.0
#     Else (feature 3 > 3400.0)
#      If (feature 3 <= 7166.666666499999)
#       If (feature 0 <= 2.5)
#        Predict: 0.0
#       Else (feature 0 > 2.5)
#        If (feature 2 <= 590.0)
#         Predict: 0.0
#        Else (feature 2 > 590.0)
#         Predict: 1.0
#      Else (feature 3 > 7166.666666499999)
#       If (feature 2 <= 710.0)
#        If (feature 2 <= 690.0)
#         Predict: 1.0
#        Else (feature 2 > 690.0)
#         If (feature 3 <= 17708.3333335)
#          Predict: 0.0
#         Else (feature 3 > 17708.3333335)
#          Predict: 1.0
#       Else (feature 2 > 710.0)
#        Predict: 1.0
#   Tree 4 (weight 1.0):
#     If (feature 3 <= 6291.666666499999)
#      If (feature 3 <= 2846.6666665000002)
#       If (feature 3 <= 0.0416665)
#        Predict: 0.0
#       Else (feature 3 > 0.0416665)
#        If (feature 3 <= 2254.8333334999998)
#         Predict: 1.0
#        Else (feature 3 > 2254.8333334999998)
#         If (feature 3 <= 2653.3333334999998)
#          Predict: 0.0
#         Else (feature 3 > 2653.3333334999998)
#          Predict: 1.0
#      Else (feature 3 > 2846.6666665000002)
#       If (feature 2 <= 750.0)
#        If (feature 2 <= 590.0)
#         Predict: 0.0
#        Else (feature 2 > 590.0)
#         If (feature 3 <= 5437.5)
#          Predict: 1.0
#         Else (feature 3 > 5437.5)
#          Predict: 0.0
#       Else (feature 2 > 750.0)
#        Predict: 1.0
#     Else (feature 3 > 6291.666666499999)
#      If (feature 0 <= 3.5)
#       If (feature 3 <= 6875.0)
#        Predict: 1.0
#       Else (feature 3 > 6875.0)
#        Predict: 0.0
#      Else (feature 0 > 3.5)
#       If (feature 3 <= 7166.666666499999)
#        If (feature 0 <= 5.5)
#         Predict: 1.0
#        Else (feature 0 > 5.5)
#         If (feature 2 <= 690.0)
#          Predict: 1.0
#         Else (feature 2 > 690.0)
#          Predict: 0.0
#       Else (feature 3 > 7166.666666499999)
#        Predict: 1.0
#   Tree 5 (weight 1.0):
#     If (feature 2 <= 650.0)
#      If (feature 0 <= 6.5)
#       If (feature 0 <= 5.5)
#        Predict: 1.0
#       Else (feature 0 > 5.5)
#        If (feature 2 <= 550.0)
#         Predict: 0.0
#        Else (feature 2 > 550.0)
#         If (feature 3 <= 6481.25)
#          Predict: 0.0
#         Else (feature 3 > 6481.25)
#          Predict: 1.0
#      Else (feature 0 > 6.5)
#       Predict: 1.0
#     Else (feature 2 > 650.0)
#      If (feature 0 <= 2.5)
#       If (feature 2 <= 730.0)
#        Predict: 0.0
#       Else (feature 2 > 730.0)
#        Predict: 1.0
#      Else (feature 0 > 2.5)
#       If (feature 3 <= 625.0)
#        Predict: 0.0
#       Else (feature 3 > 625.0)
#        Predict: 1.0
#   Tree 6 (weight 1.0):
#     If (feature 2 <= 650.0)
#      If (feature 2 <= 610.0)
#       If (feature 3 <= 3250.0)
#        If (feature 3 <= 1773.166667)
#         Predict: 0.0
#        Else (feature 3 > 1773.166667)
#         Predict: 1.0
#       Else (feature 3 > 3250.0)
#        If (feature 3 <= 5195.875)
#         Predict: 0.0
#        Else (feature 3 > 5195.875)
#         Predict: 1.0
#      Else (feature 2 > 610.0)
#       If (feature 3 <= 6481.25)
#        If (feature 0 <= 7.5)
#         If (feature 3 <= 1435.8333335)
#          Predict: 1.0
#         Else (feature 3 > 1435.8333335)
#          Predict: 0.0
#        Else (feature 0 > 7.5)
#         Predict: 1.0
#       Else (feature 3 > 6481.25)
#        Predict: 1.0
#     Else (feature 2 > 650.0)
#      If (feature 0 <= 2.5)
#       Predict: 0.0
#      Else (feature 0 > 2.5)
#       If (feature 2 <= 730.0)
#        If (feature 0 <= 8.5)
#         Predict: 1.0
#        Else (feature 0 > 8.5)
#         Predict: 0.0
#       Else (feature 2 > 730.0)
#        Predict: 1.0
#   Tree 7 (weight 1.0):
#     If (feature 0 <= 7.5)
#      If (feature 3 <= 6291.666666499999)
#       If (feature 1 in {2.0})
#        Predict: 0.0
#       Else (feature 1 not in {2.0})
#        If (feature 2 <= 650.0)
#         If (feature 0 <= 3.5)
#          Predict: 1.0
#         Else (feature 0 > 3.5)
#          Predict: 0.0
#        Else (feature 2 > 650.0)
#         Predict: 1.0
#      Else (feature 3 > 6291.666666499999)
#       If (feature 0 <= 3.5)
#        Predict: 0.0
#       Else (feature 0 > 3.5)
#        If (feature 3 <= 8041.666667)
#         Predict: 1.0
#        Else (feature 3 > 8041.666667)
#         If (feature 3 <= 8583.333333499999)
#          Predict: 0.0
#         Else (feature 3 > 8583.333333499999)
#          Predict: 1.0
#     Else (feature 0 > 7.5)
#      If (feature 2 <= 730.0)
#       If (feature 3 <= 2611.6666665000002)
#        Predict: 0.0
#       Else (feature 3 > 2611.6666665000002)
#        If (feature 2 <= 670.0)
#         Predict: 1.0
#        Else (feature 2 > 670.0)
#         If (feature 0 <= 8.5)
#          Predict: 1.0
#         Else (feature 0 > 8.5)
#          Predict: 0.0
#      Else (feature 2 > 730.0)
#       Predict: 1.0
#   Tree 8 (weight 1.0):
#     If (feature 0 <= 8.5)
#      If (feature 2 <= 590.0)
#       Predict: 0.0
#      Else (feature 2 > 590.0)
#       If (feature 3 <= 6481.25)
#        If (feature 3 <= 5880.041667)
#         If (feature 3 <= 0.0416665)
#          Predict: 0.0
#         Else (feature 3 > 0.0416665)
#          Predict: 1.0
#        Else (feature 3 > 5880.041667)
#         Predict: 0.0
#       Else (feature 3 > 6481.25)
#        If (feature 3 <= 12083.333333)
#         Predict: 1.0
#        Else (feature 3 > 12083.333333)
#         If (feature 3 <= 17708.3333335)
#          Predict: 0.0
#         Else (feature 3 > 17708.3333335)
#          Predict: 1.0
#     Else (feature 0 > 8.5)
#      Predict: 1.0
#   Tree 9 (weight 1.0):
#     If (feature 3 <= 2331.25)
#      If (feature 3 <= 1125.0)
#       If (feature 2 <= 730.0)
#        If (feature 2 <= 710.0)
#         If (feature 2 <= 610.0)
#          Predict: 1.0
#         Else (feature 2 > 610.0)
#          Predict: 0.0
#        Else (feature 2 > 710.0)
#         Predict: 0.0
#       Else (feature 2 > 730.0)
#        Predict: 1.0
#      Else (feature 3 > 1125.0)
#       Predict: 1.0
#     Else (feature 3 > 2331.25)
#      If (feature 0 <= 8.5)
#       If (feature 2 <= 650.0)
#        If (feature 3 <= 6481.25)
#         Predict: 0.0
#        Else (feature 3 > 6481.25)
#         Predict: 1.0
#       Else (feature 2 > 650.0)
#        If (feature 1 in {2.0})
#         Predict: 0.0
#        Else (feature 1 not in {2.0})
#         Predict: 1.0
#      Else (feature 0 > 8.5)
#       Predict: 1.0
#   Tree 10 (weight 1.0):
#     If (feature 2 <= 650.0)
#      If (feature 1 in {2.0})
#       Predict: 1.0
#      Else (feature 1 not in {2.0})
#       If (feature 0 <= 4.5)
#        Predict: 1.0
#       Else (feature 0 > 4.5)
#        If (feature 0 <= 6.5)
#         If (feature 3 <= 6481.25)
#          Predict: 0.0
#         Else (feature 3 > 6481.25)
#          Predict: 1.0
#        Else (feature 0 > 6.5)
#         If (feature 2 <= 610.0)
#          Predict: 1.0
#         Else (feature 2 > 610.0)
#          Predict: 0.0
#     Else (feature 2 > 650.0)
#      If (feature 1 in {2.0,6.0})
#       If (feature 0 <= 5.5)
#        Predict: 0.0
#       Else (feature 0 > 5.5)
#        If (feature 2 <= 690.0)
#         If (feature 3 <= 4625.0)
#          Predict: 0.0
#         Else (feature 3 > 4625.0)
#          Predict: 1.0
#        Else (feature 2 > 690.0)
#         Predict: 0.0
#      Else (feature 1 not in {2.0,6.0})
#       If (feature 0 <= 9.5)
#        If (feature 3 <= 625.0)
#         If (feature 2 <= 770.0)
#          Predict: 0.0
#         Else (feature 2 > 770.0)
#          Predict: 1.0
#        Else (feature 3 > 625.0)
#         Predict: 1.0
#       Else (feature 0 > 9.5)
#        Predict: 0.0
#   Tree 11 (weight 1.0):
#     If (feature 2 <= 550.0)
#      Predict: 0.0
#     Else (feature 2 > 550.0)
#      If (feature 3 <= 3752.7083334999998)
#       If (feature 3 <= 0.0416665)
#        Predict: 0.0
#       Else (feature 3 > 0.0416665)
#        If (feature 3 <= 2041.6666665)
#         Predict: 1.0
#        Else (feature 3 > 2041.6666665)
#         If (feature 3 <= 2653.3333334999998)
#          Predict: 0.0
#         Else (feature 3 > 2653.3333334999998)
#          Predict: 1.0
#      Else (feature 3 > 3752.7083334999998)
#       If (feature 2 <= 650.0)
#        If (feature 0 <= 3.5)
#         Predict: 0.0
#        Else (feature 0 > 3.5)
#         If (feature 3 <= 4812.5)
#          Predict: 0.0
#         Else (feature 3 > 4812.5)
#          Predict: 1.0
#       Else (feature 2 > 650.0)
#        If (feature 1 in {2.0})
#         Predict: 0.0
#        Else (feature 1 not in {2.0})
#         Predict: 1.0
#   Tree 12 (weight 1.0):
#     If (feature 0 <= 2.5)
#      Predict: 0.0
#     Else (feature 0 > 2.5)
#      If (feature 2 <= 730.0)
#       If (feature 0 <= 6.5)
#        If (feature 3 <= 2679.166667)
#         Predict: 1.0
#        Else (feature 3 > 2679.166667)
#         Predict: 0.0
#       Else (feature 0 > 6.5)
#        If (feature 2 <= 710.0)
#         Predict: 1.0
#        Else (feature 2 > 710.0)
#         Predict: 0.0
#      Else (feature 2 > 730.0)
#       If (feature 3 <= 3250.0)
#        If (feature 0 <= 4.5)
#         Predict: 0.0
#        Else (feature 0 > 4.5)
#         If (feature 0 <= 6.5)
#          Predict: 1.0
#         Else (feature 0 > 6.5)
#          Predict: 0.0
#       Else (feature 3 > 3250.0)
#        Predict: 1.0
#   Tree 13 (weight 1.0):
#     If (feature 0 <= 3.5)
#      If (feature 3 <= 3722.9166665000002)
#       If (feature 2 <= 670.0)
#        Predict: 1.0
#       Else (feature 2 > 670.0)
#        Predict: 0.0
#      Else (feature 3 > 3722.9166665000002)
#       Predict: 0.0
#     Else (feature 0 > 3.5)
#      If (feature 2 <= 730.0)
#       If (feature 2 <= 590.0)
#        If (feature 1 in {2.0})
#         Predict: 0.0
#        Else (feature 1 not in {2.0})
#         If (feature 3 <= 2679.166667)
#          Predict: 1.0
#         Else (feature 3 > 2679.166667)
#          Predict: 0.0
#       Else (feature 2 > 590.0)
#        If (feature 2 <= 690.0)
#         Predict: 1.0
#        Else (feature 2 > 690.0)
#         If (feature 0 <= 8.5)
#          Predict: 1.0
#         Else (feature 0 > 8.5)
#          Predict: 0.0
#      Else (feature 2 > 730.0)
#       If (feature 1 in {1.0,3.0})
#        If (feature 3 <= 3250.0)
#         If (feature 1 in {1.0})
#          Predict: 0.0
#         Else (feature 1 not in {1.0})
#          Predict: 1.0
#        Else (feature 3 > 3250.0)
#         Predict: 1.0
#       Else (feature 1 not in {1.0,3.0})
#        Predict: 1.0
#   Tree 14 (weight 1.0):
#     If (feature 3 <= 3483.3333334999998)
#      If (feature 2 <= 730.0)
#       If (feature 3 <= 2185.416667)
#        If (feature 3 <= 1773.166667)
#         If (feature 1 in {0.0,1.0,3.0,6.0})
#          Predict: 0.0
#         Else (feature 1 not in {0.0,1.0,3.0,6.0})
#          Predict: 1.0
#        Else (feature 3 > 1773.166667)
#         Predict: 1.0
#       Else (feature 3 > 2185.416667)
#        If (feature 1 in {0.0})
#         Predict: 0.0
#        Else (feature 1 not in {0.0})
#         If (feature 2 <= 610.0)
#          Predict: 1.0
#         Else (feature 2 > 610.0)
#          Predict: 0.0
#      Else (feature 2 > 730.0)
#       If (feature 3 <= 0.0416665)
#        Predict: 0.0
#       Else (feature 3 > 0.0416665)
#        Predict: 1.0
#     Else (feature 3 > 3483.3333334999998)
#      If (feature 3 <= 7166.666666499999)
#       If (feature 2 <= 650.0)
#        If (feature 3 <= 4812.5)
#         Predict: 0.0
#        Else (feature 3 > 4812.5)
#         If (feature 3 <= 5838.375)
#          Predict: 1.0
#         Else (feature 3 > 5838.375)
#          Predict: 0.0
#       Else (feature 2 > 650.0)
#        If (feature 1 in {2.0})
#         Predict: 0.0
#        Else (feature 1 not in {2.0})
#         Predict: 1.0
#      Else (feature 3 > 7166.666666499999)
#       Predict: 1.0
#   Tree 15 (weight 1.0):
#     If (feature 3 <= 12083.333333)
#      If (feature 0 <= 4.5)
#       If (feature 3 <= 1773.166667)
#        Predict: 1.0
#       Else (feature 3 > 1773.166667)
#        If (feature 3 <= 2898.3333334999998)
#         Predict: 0.0
#        Else (feature 3 > 2898.3333334999998)
#         If (feature 1 in {0.0,2.0})
#          Predict: 0.0
#         Else (feature 1 not in {0.0,2.0})
#          Predict: 1.0
#      Else (feature 0 > 4.5)
#       If (feature 2 <= 650.0)
#        If (feature 0 <= 7.5)
#         If (feature 3 <= 6481.25)
#          Predict: 0.0
#         Else (feature 3 > 6481.25)
#          Predict: 1.0
#        Else (feature 0 > 7.5)
#         Predict: 1.0
#       Else (feature 2 > 650.0)
#        If (feature 3 <= 3400.0)
#         If (feature 0 <= 6.5)
#          Predict: 1.0
#         Else (feature 0 > 6.5)
#          Predict: 0.0
#        Else (feature 3 > 3400.0)
#         Predict: 1.0
#     Else (feature 3 > 12083.333333)
#      If (feature 1 in {2.0})
#       Predict: 0.0
#      Else (feature 1 not in {2.0})
#       Predict: 1.0
#   Tree 16 (weight 1.0):
#     If (feature 2 <= 730.0)
#      If (feature 2 <= 650.0)
#       If (feature 3 <= 2331.25)
#        Predict: 1.0
#       Else (feature 3 > 2331.25)
#        If (feature 0 <= 7.5)
#         If (feature 0 <= 5.5)
#          Predict: 1.0
#         Else (feature 0 > 5.5)
#          Predict: 0.0
#        Else (feature 0 > 7.5)
#         Predict: 1.0
#      Else (feature 2 > 650.0)
#       If (feature 3 <= 625.0)
#        Predict: 0.0
#       Else (feature 3 > 625.0)
#        If (feature 3 <= 7166.666666499999)
#         If (feature 0 <= 7.5)
#          Predict: 1.0
#         Else (feature 0 > 7.5)
#          Predict: 0.0
#        Else (feature 3 > 7166.666666499999)
#         Predict: 1.0
#     Else (feature 2 > 730.0)
#      If (feature 1 in {1.0,4.0,5.0})
#       If (feature 0 <= 7.5)
#        If (feature 0 <= 6.5)
#         If (feature 0 <= 4.5)
#          Predict: 0.0
#         Else (feature 0 > 4.5)
#          Predict: 1.0
#        Else (feature 0 > 6.5)
#         Predict: 0.0
#       Else (feature 0 > 7.5)
#        Predict: 1.0
#      Else (feature 1 not in {1.0,4.0,5.0})
#       Predict: 1.0
#   Tree 17 (weight 1.0):
#     If (feature 2 <= 730.0)
#      If (feature 3 <= 2331.25)
#       Predict: 1.0
#      Else (feature 3 > 2331.25)
#       If (feature 0 <= 6.5)
#        If (feature 3 <= 3752.7083334999998)
#         Predict: 0.0
#        Else (feature 3 > 3752.7083334999998)
#         If (feature 3 <= 4291.666666499999)
#          Predict: 1.0
#         Else (feature 3 > 4291.666666499999)
#          Predict: 0.0
#       Else (feature 0 > 6.5)
#        If (feature 0 <= 9.5)
#         If (feature 3 <= 4625.0)
#          Predict: 0.0
#         Else (feature 3 > 4625.0)
#          Predict: 1.0
#        Else (feature 0 > 9.5)
#         Predict: 0.0
#     Else (feature 2 > 730.0)
#      If (feature 3 <= 0.0416665)
#       Predict: 0.0
#      Else (feature 3 > 0.0416665)
#       If (feature 3 <= 3250.0)
#        If (feature 1 in {1.0,4.0})
#         If (feature 3 <= 2104.1666665000002)
#          Predict: 1.0
#         Else (feature 3 > 2104.1666665000002)
#          Predict: 0.0
#        Else (feature 1 not in {1.0,4.0})
#         Predict: 1.0
#       Else (feature 3 > 3250.0)
#        Predict: 1.0
#   Tree 18 (weight 1.0):
#     If (feature 3 <= 5235.291666499999)
#      If (feature 1 in {6.0})
#       Predict: 0.0
#      Else (feature 1 not in {6.0})
#       If (feature 3 <= 1604.166667)
#        If (feature 2 <= 670.0)
#         If (feature 3 <= 1125.0)
#          Predict: 0.0
#         Else (feature 3 > 1125.0)
#          Predict: 1.0
#        Else (feature 2 > 670.0)
#         Predict: 1.0
#       Else (feature 3 > 1604.166667)
#        If (feature 2 <= 650.0)
#         If (feature 3 <= 2185.416667)
#          Predict: 1.0
#         Else (feature 3 > 2185.416667)
#          Predict: 0.0
#        Else (feature 2 > 650.0)
#         If (feature 1 in {1.0,2.0,3.0})
#          Predict: 0.0
#         Else (feature 1 not in {1.0,2.0,3.0})
#          Predict: 1.0
#     Else (feature 3 > 5235.291666499999)
#      If (feature 3 <= 12083.333333)
#       If (feature 1 in {0.0,2.0})
#        If (feature 2 <= 690.0)
#         If (feature 3 <= 8466.666666500001)
#          Predict: 1.0
#         Else (feature 3 > 8466.666666500001)
#          Predict: 0.0
#        Else (feature 2 > 690.0)
#         Predict: 1.0
#       Else (feature 1 not in {0.0,2.0})
#        If (feature 0 <= 4.5)
#         If (feature 3 <= 5437.5)
#          Predict: 1.0
#         Else (feature 3 > 5437.5)
#          Predict: 0.0
#        Else (feature 0 > 4.5)
#         Predict: 1.0
#      Else (feature 3 > 12083.333333)
#       If (feature 2 <= 710.0)
#        Predict: 0.0
#       Else (feature 2 > 710.0)
#        Predict: 1.0
#   Tree 19 (weight 1.0):
#     If (feature 3 <= 3483.3333334999998)
#      If (feature 1 in {3.0})
#       Predict: 0.0
#      Else (feature 1 not in {3.0})
#       If (feature 3 <= 3250.0)
#        If (feature 2 <= 530.0)
#         Predict: 1.0
#        Else (feature 2 > 530.0)
#         If (feature 2 <= 670.0)
#          Predict: 0.0
#         Else (feature 2 > 670.0)
#          Predict: 1.0
#       Else (feature 3 > 3250.0)
#        If (feature 2 <= 710.0)
#         Predict: 0.0
#        Else (feature 2 > 710.0)
#         Predict: 1.0
#     Else (feature 3 > 3483.3333334999998)
#      If (feature 2 <= 650.0)
#       If (feature 3 <= 4729.166667)
#        Predict: 0.0
#       Else (feature 3 > 4729.166667)
#        If (feature 2 <= 590.0)
#         Predict: 0.0
#        Else (feature 2 > 590.0)
#         If (feature 3 <= 5085.583333500001)
#          Predict: 1.0
#         Else (feature 3 > 5085.583333500001)
#          Predict: 0.0
#      Else (feature 2 > 650.0)
#       If (feature 3 <= 4291.666666499999)
#        Predict: 1.0
#       Else (feature 3 > 4291.666666499999)
#        If (feature 3 <= 4416.666666499999)
#         Predict: 0.0
#        Else (feature 3 > 4416.666666499999)
#         Predict: 1.0

# %% [markdown]
# ### 6.4 Create Predictions

# %%
## TODO : predict on test data
predictions = rf_model.transform(test)

predictions2= predictions.drop('rawPrediction', 'probability')
predictions2.show()
# Out:
# +----------+------------+----------------+-----------+-------------------+---------------+--------+--------------------+-----+----------+
# |LoanStatus|ProsperScore|EmploymentStatus|CreditScore|StatedMonthlyIncome|ListingCategory|EmpIndex|            features|label|prediction|
# +----------+------------+----------------+-----------+-------------------+---------------+--------+--------------------+-----+----------+
# |         0|         3.0|   Self-employed|      680.0|             6350.0|       Business|     2.0|[3.0,2.0,680.0,63...|    0|       0.0|
# |         0|         4.0|        Employed|      640.0|             6250.0|           Debt|     1.0|[4.0,1.0,640.0,62...|    0|       0.0|
# |         0|         6.0|        Employed|      640.0|             6000.0|           Debt|     1.0|[6.0,1.0,640.0,60...|    0|       0.0|
# |         0|         6.0|        Employed|      660.0|        3928.083333|       Business|     1.0|[6.0,1.0,660.0,39...|    0|       1.0|
# |         0|         6.0|       Full-time|      520.0|        2333.333333|           Debt|     0.0|[6.0,0.0,520.0,23...|    0|       0.0|
# |         0|         6.0|       Full-time|      580.0|             3750.0|           Debt|     0.0|[6.0,0.0,580.0,37...|    0|       0.0|
# |         0|         6.0|       Full-time|      600.0|             3500.0|        Unknown|     0.0|[6.0,0.0,600.0,35...|    0|       0.0|
# |         0|         6.0|       Full-time|      600.0|             3711.5|        Unknown|     0.0|[6.0,0.0,600.0,37...|    0|       0.0|
# |         0|         6.0|       Full-time|      600.0|        5166.666667|       Business|     0.0|[6.0,0.0,600.0,51...|    0|       0.0|
# |         0|         6.0|       Full-time|      620.0|        2333.333333|       Personal|     0.0|[6.0,0.0,620.0,23...|    0|       0.0|
# |         0|         6.0|       Full-time|      620.0|             3882.5|        Unknown|     0.0|[6.0,0.0,620.0,38...|    0|       0.0|
# |         0|         6.0|       Full-time|      660.0|        4876.583333|       Personal|     0.0|[6.0,0.0,660.0,48...|    0|       1.0|
# |         0|         6.0|       Full-time|      700.0|        6666.666667|       Business|     0.0|[6.0,0.0,700.0,66...|    0|       1.0|
# |         0|         7.0|        Employed|      660.0|        3083.333333|           Reno|     1.0|[7.0,1.0,660.0,30...|    0|       1.0|
# |         0|         8.0|        Employed|      640.0|             3500.0|          Other|     1.0|[8.0,1.0,640.0,35...|    0|       1.0|
# |         0|         8.0|        Employed|      780.0|        2916.666667|           Debt|     1.0|[8.0,1.0,780.0,29...|    0|       1.0|
# |         1|         1.0|       Full-time|      640.0|       10166.666667|           Reno|     0.0|[1.0,0.0,640.0,10...|    1|       1.0|
# |         1|         2.0|        Employed|      700.0|        5833.333333|           Debt|     1.0|[2.0,1.0,700.0,58...|    1|       0.0|
# |         1|         4.0|        Employed|      640.0|        4333.333333|           Debt|     1.0|[4.0,1.0,640.0,43...|    1|       1.0|
# |         1|         5.0|        Employed|      660.0|             2500.0|           Reno|     1.0|[5.0,1.0,660.0,25...|    1|       1.0|
# +----------+------------+----------------+-----------+-------------------+---------------+--------+--------------------+-----+----------+
# only showing top 20 rows

# %% [markdown]
# ## Step 7: Evaluate the model.
#
# Let us check to see how the model did, using accuracy as a measure.

# %%
predictions_test = rf_model.transform(test)  # Hint : test
predictions_train = rf_model.transform(training)  # Hint : training

# %% [markdown]
# ### 7.1 Accuracy

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                              metricName="accuracy")

print("Training set accuracy = " , evaluator.evaluate(predictions_train))
print("Test set accuracy = " , evaluator.evaluate(predictions_test))
# Out:
# Training set accuracy =  0.8163265306122449
# Test set accuracy =  0.7358490566037735

# %% [markdown]
# #### Is RF more stable than DTs ?
# Do a few runs, and see the accuracy above.
# Does it vary a lot like Decision Trees before?
# Probably not.  Why do you think it is?

# %% [markdown]
# ### 7.2 Confusion Matrix

# %%
cm = predictions_test.groupBy('LoanStatus').pivot('prediction', [0,1]).count().na.fill(0).orderBy('LoanStatus')
cm.show()
# Out:
# +----------+---+---+
# |LoanStatus|  0|  1|
# +----------+---+---+
# |         0| 10|  6|
# |         1|  8| 29|
# +----------+---+---+

# %%
import seaborn as sns

cm_pd = cm.toPandas()
cm_pd.set_index("LoanStatus", inplace=True)
# print(cm_pd)

# colormaps : cmap="YlGnBu" , cmap="Greens", cmap="Blues",  cmap="Reds"
sns.heatmap(cm_pd, annot=True, fmt=',', cmap="Blues")

# %% [markdown]
# ### 7.3 - AUC
#
# For scewed data 'Area Under Precision Recall' curve might be better indicator.
# https://stats.stackexchange.com/questions/90779/area-under-the-roc-curve-or-area-under-the-pr-curve-for-imbalanced-data

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator

# default metrics for BinaryClassificationEvaluator is 'areaUnderCurve'
evaluator1 = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", metricName='areaUnderROC')

print("AUC for training: " , evaluator1.evaluate(predictions_train))
print ("AUC for test : " , evaluator1.evaluate(predictions_test))

evaluator2 = BinaryClassificationEvaluator(rawPredictionCol="rawPrediction", metricName='areaUnderPR')
print("Area under PR for training: " , evaluator2.evaluate(predictions_train))
print ("Area under PR for test : " , evaluator2.evaluate(predictions_test))
# Out:
# AUC for training:  0.9186658249158248
# AUC for test :  0.7635135135135137
# Area under PR for training:  0.9628402088841111
# Area under PR for test :  0.8881679267806732

# %% [markdown]
# ## Step 8: Improve Accuracy
#
# ### Add more data
# In Step-1 change the 'datafile' to the full dataset.
# And see how the accuracy above changes
#
# ### Add more features
# Look at the schema of the full dataset.  Are there any columns you want to add
